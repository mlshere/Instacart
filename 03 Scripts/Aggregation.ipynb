# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
# Import pkl data 
path = '/Users/bobbi/Careerfoundry/InstacartBasketAnalysis_01_25'

df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'merged_ords_prods.pkl'))

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0
#
#   existing_merge                             product_name  aisle_id  \
# ...

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# # 03. Functions

# %% [markdown]
# ### If-Statements with User-Defined Functions

# %%
# define a price label function

def price_label(row):
  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Create a price_range column
df['price_range'] = df.apply(price_label, axis = 1)

df.head()
# Out:
# /var/folders/bs/25x482152nx68y1wp8l2g42c0000gn/T/ipykernel_36021/158387950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df_ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
print(df['price_range'] == 'High range')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Name: price_range, Length: 1000000, dtype: bool

# %%
print(df.loc[df['price_range'] == 'High range', 'prices'])
# Out:
# 398       19.6
# 401       19.6
# 436       23.2
# 465       23.2
# 480       23.2
#           ...
# 999329    24.6
# 999332    25.0
# 999388    25.0
# 999394    19.6
# 999880    20.8
# Name: prices, Length: 12425, dtype: float64

# %% [markdown]
# ### If-Statements with the loc() Function

# %%
# If statement with loc() function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/bs/25x482152nx68y1wp8l2g42c0000gn/T/ipykernel_36021/3509703962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %% [markdown]
# #### In this following section I tried to make sense of the outliners in price. I found two at 99999.0 and 14900.0 that didn't make sense

# %%
df.describe()
# Out:
#            order_id         user_id    order_number  orders_day_of_week  \
# count  1.000000e+06  1000000.000000  1000000.000000      1000000.000000
# mean   1.712098e+06     3295.070459       17.313612            2.765702
# std    9.870102e+05     1866.882221       17.931306            2.091348
# min    8.000000e+00        1.000000        1.000000            0.000000
# 25%    8.620670e+05     1699.000000        5.000000            1.000000
# 50%    1.711365e+06     3350.000000       11.000000            3.000000
# 75%    2.563843e+06     4937.000000       24.000000            5.000000
# max    3.420853e+06     6474.000000       99.000000            6.000000
#
#        order_hour_of_day  days_since_last_order      product_id  \
# count     1000000.000000          936384.000000  1000000.000000
# mean           13.416690              11.062006    25595.891283
# std             4.221497               8.811708    14077.246950
# ...

# %%
df[df['prices'] == 99999.0]
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 128911    183964      873             3                   0
# 128924   1851256      873             4                   6
# 284218   1915696     1893             1                   5
# 284229   2763293     1893             2                   4
# 284252   2564805     1893             4                   1
# 499076    949012     3339             1                   1
# 499119    420057     3339             2                   0
# 499141   1511997     3339             3                   1
# 499158   1153448     3339             4                   4
# 499180   2669259     3339             5                   4
# 527458    965345     3531            27                   2
# 767471   2291230     5034             6                   1
# 767485   2324832     5034             7                   6
# 953246    323856     6175            37                   2
# 960509    842052     6222            10                   1
#
# ...

# %%
df_ords_prods_merge[df_ords_prods_merge['prices'] == 99999.0]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 128911      183964      873             3                   0
# 128924     1851256      873             4                   6
# 284218     1915696     1893             1                   5
# 284229     2763293     1893             2                   4
# 284252     2564805     1893             4                   1
# ...            ...      ...           ...                 ...
# 32079919   2249946   204099            29                   0
# 32079936   2363282   204099            31                   0
# 32125745   3181945   204395            13                   3
# 32255078   2486215   205227             7                   3
# 32255132   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 128911                   10                    7.0       33664
# 128924                   12                   13.0       33664
# ...

# %%
df_ords_prods_merge[df_ords_prods_merge['prices'] == 14900.0]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16522      3264360      135             2                   2
# 16528       892534      135             3                   0
# 53672       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 1576                     14                    5.0       21553
# 1638                     16                    4.0       21553
# ...

# %%
df_ords_prods_merge[df_ords_prods_merge['product_id'] == 21553]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16522      3264360      135             2                   2
# 16528       892534      135             3                   0
# 53672       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 1576                     14                    5.0       21553
# 1638                     16                    4.0       21553
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 15)

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['product_name'] == '2% Reduced Fat Milk']
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 4754       1244041       38             5                   0
# 4766        718156       38             6                   6
# 4784        894015       38             7                   6
# 5274       2315446       42            11                   3
# 5319        606677       43             1                   1
# ...            ...      ...           ...                 ...
# 32403069   2547959   206201            28                   0
# 32403076   1046357   206201            29                   4
# 32403085    584166   206201            30                   0
# 32403111   1125912   206201            31                   1
# 32404796    550836   206209             7                   2
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 4754                     14                   22.0       23909
# 4766                      9                   13.0       23909
# ...

# %%
# Replace 99999.0 price for 9.2 price 
df_ords_prods_merge['prices'].replace(99999.0, 9.2, inplace=True)
# Out:
# /var/folders/bs/25x482152nx68y1wp8l2g42c0000gn/T/ipykernel_36021/1643870883.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ords_prods_merge['prices'].replace(99999.0, 9.2, inplace=True)

# %%
df_ords_prods_merge[df_ords_prods_merge['product_id'] == 33664]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 128911      183964      873             3                   0
# 128924     1851256      873             4                   6
# 284218     1915696     1893             1                   5
# 284229     2763293     1893             2                   4
# 284252     2564805     1893             4                   1
# ...            ...      ...           ...                 ...
# 32079919   2249946   204099            29                   0
# 32079936   2363282   204099            31                   0
# 32125745   3181945   204395            13                   3
# 32255078   2486215   205227             7                   3
# 32255132   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 128911                   10                    7.0       33664
# 128924                   12                   13.0       33664
# ...

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['aisle_id'] == 108, 'product_name'].unique()
# Out:
# array(['Part Skim Ricotta Cheese', 'Whipped Cream Cheese',
#        'Lowfat Small Curd Cottage Cheese',
#        'Organic Cultured Cream Cheese Spread',
#        'Lowfat 2% Milkfat Cottage Cheese',
#        'Original Whipped Cream Cheese', 'Sour Cream',
#        'Original Cream Cheese', 'Pure & Natural Sour Cream',
#        'Philadelphia Original Cream Cheese', 'Whole Milk Ricotta Cheese',
#        'Original Sour Cream', 'Cream Cheese Bar', 'Light Sour Cream',
#        'Creme Fraiche', 'Organic Small Curd Cottage Cheese',
#        'Organic Sour Cream',
#        'Small Curd Lowfat 2% Milkfat Cottage Cheese',
#        'Organic Cream Cheese Bar', 'Pimento Cheese Dip',
#        'Organic Strawberry Chia Lowfat 2% Cottage Cheese',
#        'Organic Cottage Cheese Blueberry Acai Chia',
#        'Cream Cheese Spread',
#        'Dairy Free Plain Cream Cheese Style Spread',
#        'Philadelphia Cream Cheese', 'Cream Cheese',
#        'Dairy-Free Chive Cream Cheese', 'Natural Sour Cream',
# ...

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['product_name'] == '2% Low-fat Cottage Cheese']
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 38796       589249      262            27                   5
# 180766     1011761     1221             1                   5
# 180786      777715     1221             2                   6
# 180810     2276348     1221             3                   2
# 180825      772394     1221             4                   0
# ...            ...      ...           ...                 ...
# 31918826    798137   203062             2                   0
# 31918858   2890120   203062             6                   1
# 31960268   3135231   203313            13                   4
# 31999082   3115325   203530             5                   3
# 32154551    638842   204559            13                   2
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 38796                    15                    6.0       11259
# 180766                   13                    NaN       11259
# ...

# %%
# Replace Lowfat 2% Milkfat Cottage Cheese from 14900.0	to 2% Low-fat Cottage Cheese = 9.4	
df_ords_prods_merge['prices'].replace(14900.0, 9.4, inplace=True)
# Out:
# /var/folders/bs/25x482152nx68y1wp8l2g42c0000gn/T/ipykernel_36021/151309337.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ords_prods_merge['prices'].replace(14900.0, 9.4, inplace=True)

# %%
df_ords_prods_merge[df_ords_prods_merge['product_id'] == 21553]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16522      3264360      135             2                   2
# 16528       892534      135             3                   0
# 53672       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 1576                     14                    5.0       21553
# 1638                     16                    4.0       21553
# ...

# %% [markdown]
# There were two outliners that didn't make sense '2% Reduced Fat Milk' at 99999.0 price and 2% Low-fat Cottage Cheese at 14900.0. I looked in the data for a similar product to find the price and then replace the wrong price to the corresponding price.

# %%
df = df_ords_prods_merge[:1000000]

# %%
df['price_range'] = df.apply(price_label, axis = 1)

df['price_range'].value_counts()
# Out:
# /var/folders/bs/25x482152nx68y1wp8l2g42c0000gn/T/ipykernel_36021/1238421286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)
# price_range
# Mid-range product    673340
# Low-range product    314392
# High range            12268
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ### If-Statements with For-Loops

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Create new column busiest day

result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# Create a new column busiest_days

# %%
# Create a new array for new results
new_results = []

for value in df_ords_prods_merge['orders_day_of_week']:
    if value == 0 or value == 1:
        new_results.append("Busiest days")
    elif value == 4 or value == 3:
        new_results.append("Least busy days")
    else:
        new_results.append("Regularly busy")

# %%
# Use new array in the existing 'busiest_day' column
df_ords_prods_merge['busiest_day'] = new_results

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %%
# Rename column
df_ords_prods_merge.rename(columns={'busiest_day': 'busiest_days'}, inplace=True)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0
#
#   existing_merge                             product_name  aisle_id  \
# ...

# %% [markdown]
# ### Identify busies hours of the day

# %%
# Identify order frequency per hour

hourly_counts = df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)

hourly_counts
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# As the technical officer wants to separate orders per hour in three periods, I decided to establish this separation:
# * "Most orders": Above 2 million orders per hour
# * "Average orders": Under 2 million orders and above 500.000 orders per hour
# * "Fewest orders": Under 500.000 orders per hour
#
# I will use the calculated hours to create a function to classify the periods and then apply it to create a new colum 'busiest_period_of_day'

# %%
# Function

def hour_classification(hour):
    count = hourly_counts[hour]
    if count >= 2000000:
        return "Most orders"
    elif count < 2000000 and count >= 500000:
        return "Average orders"
    else:
        return "Fewest orders"

# %%
# Apply classification 

df_ords_prods_merge['busiest_period_of_day'] = df_ords_prods_merge['order_hour_of_day'].apply(hour_classification)

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       23205725
# Average orders     7909997
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0
#
#   existing_merge                             product_name  aisle_id  \
# ...

# %% [markdown]
# # 04. Export data

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_busy_day_hour_7.pkl'))
