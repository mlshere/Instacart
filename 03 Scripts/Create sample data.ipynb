# %% [markdown]
# # Creating a sample for visualizations

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import pkl data 
path = '/Users/bobbi/Careerfoundry/InstacartBasketAnalysis_01_25'

sample_data = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'subset_ords_prods_cust.pkl'))

# %%
sample_data.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  \
# 0                    NaN         196                  1
# 1                    NaN       14084                  2
# 2                    NaN       12427                  3
# 3                    NaN       26088                  4
# 4                    NaN       26405                  5
#
#                               product_name  aisle_id  ...  \
# 0                                     Soda        77  ...
# 1  Organic Unsweetened Vanilla Almond Milk        91  ...
# ...

# %%
# Create sample
np.random.seed(4)

dev = np.random.rand(len(sample_data)) <= 0.7

dev
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %%
# Random sample (70)
big = sample_data[dev]

# %%
# Random sample (30)
small = sample_data[~dev]

# %%
# Check sample
len(sample_data)
# Out:
# 30964564

# %%
len(big) + len(small)
# Out:
# 30964564

# %%
small.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
#
#     days_since_last_order  product_id  add_to_cart_order  \
# 0                     NaN         196                  1
# 2                     NaN       12427                  3
# 3                     NaN       26088                  4
# 6                    15.0       10258                  2
# 10                   15.0       13032                  6
#
#                   product_name  aisle_id  ...              ords_flag  gender  \
# 0                         Soda        77  ...  Non-frequent customer  Female
# ...

# %%
# Export small sample
small.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'sample_data.pkl'))
