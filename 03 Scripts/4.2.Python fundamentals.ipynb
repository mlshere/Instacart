# %% [markdown]
# # Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Working with Python data types

# %%
# Code 3 different ways to reach 100
a = 50
b = 30
c = 20

# %%
result1 = a + b + c
print("Result 1: ", result1)
# Out:
# Result 1:  100

# %%
result2 = (a * 3) - b - c
print("Result 2:", result2)
# Out:
# Result 2: 100

# %%
result3 = (b * 2) + (c * 2)
print("Result 3:", result3)
# Out:
# Result 3: 100

# %%
# Code 2 floating-point variables and divide them
float1 = 9.7
float2 = 2.3

# %%
result = float1 / float2
print("Result:", result)
# Out:
# Result: 4.217391304347826

# %%
# Construct a short word by concatenating strings 
short_word = "Py" + "thon"  
print("Short word:", short_word)
# Out:
# Short word: Python

# %%
sentence1 = "Hack" + " " + "the" + " " + "planet" + "!"
sentence2 = "I learn" + " " + "data analysis."
print("Sentence 1:", sentence1)
print("Sentence 2:", sentence2)
# Out:
# Sentence 1: Hack the planet!
# Sentence 2: I learn data analysis.
